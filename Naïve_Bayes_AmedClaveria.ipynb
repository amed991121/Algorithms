# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# Entrenar modelo Naive Bayes con tablas de frecuencia

# %%
def entrenar_naive_bayes(datos_entrenamiento, idx_clase, dominio, cabecera, tipos):

    tabla_frecuencia = {}

    for idx_col, atributo in enumerate(cabecera.iloc[0]):
        tabla_frecuencia[atributo] = {}
        columna = datos_entrenamiento.iloc[:, idx_col]

        if idx_col == idx_clase:
            for idx, valor in columna.items():
                valor_clase = datos_entrenamiento.iloc[idx, idx_clase]
                if valor_clase not in tabla_frecuencia[atributo]:
                    tabla_frecuencia[atributo][valor_clase] = {}
                if valor not in tabla_frecuencia[atributo][valor_clase]:
                    tabla_frecuencia[atributo][valor_clase][valor] = 0
                tabla_frecuencia[atributo][valor_clase][valor] += 1
        else:
            for clase in dominio.iloc[0, idx_clase].split(' '):
                if clase not in tabla_frecuencia[atributo]:
                    tabla_frecuencia[atributo][clase] = {}
                    for idx, valor in columna.items():
                        if valor not in tabla_frecuencia[atributo][clase]:
                            tabla_frecuencia[atributo][clase][valor] = 0

                        valor_clase = datos_entrenamiento.iloc[idx, idx_clase]
                        if valor_clase == clase:
                            tabla_frecuencia[atributo][clase][valor] += 1


    # Verosimilitud
    cabecera_cont = [cabecera.iloc[0, idx] for idx in range(len(cabecera.columns)) if tipos.iloc[0, idx] == 'continuous']

    for atributo, clases in tabla_frecuencia.items():
        for clase, valores in clases.items():
            total = sum(valores.values())
            if atributo in cabecera_cont:
                # Para atributos continuos, calcular media y desviación estándar
                freq_dict = valores
                all_values = []
                for valor, count in freq_dict.items():
                    all_values.extend([float(valor)] * int(count))
                all_values = pd.Series(all_values)
                media = all_values.mean()
                std_dev = all_values.std(ddof=0)
                tabla_frecuencia[atributo][clase] = {'mean': media, 'std': std_dev}
            else:
                idx_atributo = cabecera.iloc[0].tolist().index(atributo)

                for valor, count in valores.items():
                    if count == 0:
                        # Aplicar suavizado de Laplace
                        for value, count in valores.items():
                            tabla_frecuencia[atributo][clase][value] += 1
                            tabla_frecuencia[atributo][clase][value] /= (total + len(valores))

                for valor, count in valores.items():
                    if not isinstance(count, float):
                        if valor in list(dominio[idx_clase])[0].split(' '):
                                tabla_frecuencia[atributo][clase][valor] = count / len(datos_entrenamiento)
                        else:
                            tabla_frecuencia[atributo][clase][valor] = count / total

    return tabla_frecuencia

# %% [markdown]
# Pedecir usando Naive Bayes

# %%
def clasificar_naive_bayes(instancia, tabla_frecuencia, cabecera, tipos, dominio, idx_clase):
    cabecera_cont = [cabecera.iloc[0, idx] for idx in range(len(cabecera.columns)) if tipos.iloc[0, idx] == 'continuous']
    probabilidades = {}
    for clases in dominio.iloc[0, idx_clase].split(' '):
        probabilidades[clases] = 1

    for atributo, clases in tabla_frecuencia.items():
        for clase, valores in clases.items():
            probabilidad_A_I = 1
            probabilidad_A = 0
            valor = instancia[cabecera.iloc[0].tolist().index(atributo)]
            if atributo in cabecera_cont:
                media = valores['mean']
                std_dev = valores['std']
                probabilidad_A_I *= (1 / (math.sqrt(2 * math.pi) * std_dev)) * math.exp(-((float(valor) - media) ** 2) / (2 * (std_dev ** 2)))
                if probabilidad_A_I == 0:
                    probabilidad_A_I = 1e-5
            elif next(iter(valores)) == clase:
                probabilidad_A = valores.get(clase, 0)
            else:
                probabilidad_A_I *= valores.get(valor, 0)

            if probabilidad_A != 0:
                probabilidades[clase] *= probabilidad_A
            else:
                probabilidades[clase] *= probabilidad_A_I

    return probabilidades

# %% [markdown]
# Validacion iterativa de K-Fold Cross

# %%
def k_fold_cross_validation(datos, idx_clase, dominio, cabecera, tipos, K):

    indices = np.arange(len(datos))
    np.random.shuffle(indices)
    folds = np.array_split(indices, K)
    model_accuracies = []

    for i in range(K):
        test_indices = folds[i]
        train_indices = np.concatenate(folds[:i] + folds[i+1:])

        datos_entrenamiento = datos.iloc[train_indices].reset_index(drop=True)
        datos_prueba = datos.iloc[test_indices].reset_index(drop=True)

        tabla_frecuencia = entrenar_naive_bayes(datos_entrenamiento, idx_clase, dominio, cabecera, tipos)

        aciertos = 0
        for idx, instancia in datos_prueba.iterrows():
            probabilidades = clasificar_naive_bayes(instancia, tabla_frecuencia, cabecera, tipos, dominio, idx_clase)
            clase_predicha = max(probabilidades, key=probabilidades.get)
            if clase_predicha == instancia[idx_clase]:
                aciertos += 1

        accuracy = aciertos / len(datos_prueba)
        model_accuracies.append((tabla_frecuencia, accuracy))

    # Calcular accuracy promedio
    avg_accuracy = sum(x[1] for x in model_accuracies) / len(model_accuracies)
    # Seleccionar el modelo cuyo accuracy esté más cercano al promedio
    best_model = min(model_accuracies, key=lambda x: abs(x[1] - avg_accuracy))

    #print("Accuracy promedio:", avg_accuracy)
    #print("Modelo seleccionado con accuracy:", best_model[1])

    return best_model  # Retorna una tupla (tabla_frecuencia, accuracy)

# %% [markdown]
# Metodo Holdout

# %%
def holdout(datos, training_percentage, K, dominio, cabecera, tipos, idx_clase):
    # Dividir el conjunto de datos en entrenamiento y prueba
    indices = np.arange(len(datos))
    np.random.shuffle(indices)
    split_point = int(len(datos) * training_percentage)
    train_indices = indices[:split_point]
    test_indices = indices[split_point:]
    training_set = datos.iloc[train_indices].reset_index(drop=True)
    test_set = datos.iloc[test_indices].reset_index(drop=True)

    best_model = k_fold_cross_validation(training_set, idx_clase, dominio, cabecera, tipos, K)


    clases = list(dominio.iloc[0, idx_clase].split(' '))

    cm = {clase: {c: 0 for c in clases} for clase in clases}

    for _, instancia in test_set.iterrows():
        predicted_prob = clasificar_naive_bayes(instancia, best_model[0], cabecera, tipos, dominio, idx_clase)
        predicted_class = max(predicted_prob, key=predicted_prob.get)
        actual_class = instancia[idx_clase]
        cm[actual_class][predicted_class] += 1
        # Acumular los detalles de cada instancia en una lista (inicializándola si es la primera iteración)
        if 'tabla_resultados' not in locals():
            tabla_resultados = []
        tabla_resultados.append({
            "Instancia": instancia.to_dict(),
            "Clase Actual": actual_class,
            "Clase Predicha": predicted_class,
            "Probabilidades": predicted_prob
        })

        # Si ya se han procesado todas las instancias del conjunto de prueba, mostrar la tabla
        if len(tabla_resultados) == len(test_set):
            resultados_df = pd.DataFrame(tabla_resultados)
            print("Tabla de resultados:")
            tabla_formateada = pd.DataFrame({
                'Instancia': [str(inst) for inst in resultados_df['Instancia']],
                'Clase Actual': resultados_df['Clase Actual'],
                'Clase Predicha': resultados_df['Clase Predicha'],
                'Probabilidades': [str(prob) for prob in resultados_df['Probabilidades']]
            })

            print(tabla_formateada.to_string(index=True))
    # Mostrar la matriz de confusión
    print("Matriz de confusión:")
    matrix = pd.DataFrame(cm)
    matrix.index.name = "Clase Actual"
    matrix.columns.name = "Clase Predicho"
    print(matrix)

    return cm

# %%
def main():
    # Configuración hardcoded
    filename = "/content/drive/MyDrive/Colab Notebooks/iris_mixed.csv"
    N = 10  # Numero de iteraciones
    K = 5 # Numero de Folds
    training_percentage = 0.7

    # Cargar datos
    data = pd.read_csv(filename, header = None)
    cabecera = data.iloc[[0]].reset_index(drop=True)
    dominio = data.iloc[[1]].reset_index(drop=True)
    tipos = data.iloc[[2]].reset_index(drop=True)
    datos = data.iloc[3:].reset_index(drop=True)
    idx_clase = tipos.columns[tipos.iloc[0] == 'class'][0]

    all_confusion_matrices = []
    clases = list(dominio.iloc[0, idx_clase].split(' '))

    for iteration in range(N):
        print("\nIteración:", iteration + 1)

        all_confusion_matrices.append(holdout(datos, training_percentage, K, dominio, cabecera, tipos, idx_clase))

    # Calcular la matriz promedio (promediando cada componente)
    avg_confusion = {}
    for clase in clases:
        avg_confusion[clase] = {}
        for c in clases:
            avg_confusion[clase][c] = np.mean([matriz[clase][c] for matriz in all_confusion_matrices])

    print("-" * 50)
    print("Matriz de confusión promedio:")
    matrix = pd.DataFrame(avg_confusion)
    matrix.index.name = "Clase Actual"
    matrix.columns.name = "Clase Predicho"
    print(matrix)

    # Calcular las métricas a partir de la matriz promedio
    total = sum(avg_confusion[a][p] for a in clases for p in clases)
    exactitud = sum(avg_confusion[c][c] for c in clases) / total if total else 0

    sensibilidades = {}
    especificidades = {}
    f1_scores = {}
    precisiones = {}
    for c in clases:
        TP = avg_confusion[c][c]
        TN = sum(avg_confusion[other][other] for other in clases if other != c)
        FP = sum(avg_confusion[other][c] for other in clases if other != c)
        FN = total - TP - FP - TN
        P = sum(avg_confusion[c][other] for other in clases)
        N = total - P

        sensibilidad = TP / P if P > 0 else 0
        especificidad = TN / N if N > 0 else 0
        precision = TP / (TP + FP) if (TP + FP) > 0 else 0
        f1 = (2 * precision * sensibilidad) / (precision + sensibilidad) if (precision + sensibilidad) > 0 else 0
        sensibilidades[c] = sensibilidad
        especificidades[c] = especificidad
        f1_scores[c] = f1
        precisiones[c] = precision

    print("-" * 50)
    print("Métricas finales:")
    print("Exactitud (promedio):", exactitud)
    print("Sensibilidad (promedio):", sensibilidades)
    print("Especificidad (promedio):", especificidades)
    print("Precisión (promedio):", precisiones)
    print("F1-score (promedio):", f1_scores)
    print("-" * 50)

if __name__ == "__main__":
    main()
# Out:
# Iteración: 1
# Tabla de resultados:
#                                                                          Instancia     Clase Actual   Clase Predicha                                                                                                                 Probabilidades
# 0    {0: '6.4', 1: '(1.998, 2.8]', 2: '5.3', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica       {'Iris-setosa': 5.22292018194055e-97, 'Iris-virginica': 0.042467488046429996, 'Iris-versicolor': 0.00016987788398333534}
# 1     {0: '5.4', 1: '(2.8, 3.6]', 2: '4.5', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor        {'Iris-setosa': 6.971503580747784e-59, 'Iris-virginica': 0.0003178636283275255, 'Iris-versicolor': 0.05012236800351265}
# 2     {0: '6.9', 1: '(2.8, 3.6]', 2: '4.9', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor       {'Iris-setosa': 1.2498611675350216e-80, 'Iris-virginica': 0.003818377249859368, 'Iris-versicolor': 0.012686339362059259}
# 3      {0: '4.3', 1: '(2.8, 3.6]', 2: '1.1', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa      {'Iris-setosa': 0.006619245996041223, 'Iris-virginica': 2.4214708025107076e-19, 'Iris-versicolor': 9.343959615844347e-19}
# 4    {0: '6.2', 1: '(1.998, 2.8]', 2: '4.8', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica       {'Iris-setosa': 4.521584253514631e-74, 'Iris-virginica': 0.017494614734862315, 'Iris-versicolor': 0.0016855411735224235}
# 5      {0: '6.7', 1: '(2.8, 3.6]', 2: '5.7', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica      {'Iris-setosa': 3.6416595102149915e-117, 'Iris-virginica': 0.06975853154211688, 'Iris-versicolor': 8.224808990878447e-06}
# 6      {0: '5.1', 1: '(2.8, 3.6]', 2: '1.7', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa        {'Iris-setosa': 0.2496170351312926, 'Iris-virginica': 1.7251193543650528e-14, 'Iris-versicolor': 1.633986315269493e-12}
# 7   {0: '5.6', 1: '(1.998, 2.8]', 2: '4.2', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor       {'Iris-setosa': 7.036866514043447e-50, 'Iris-virginica': 0.00010702195509659516, 'Iris-versicolor': 0.06223559837338939}
# 8      {0: '6.8', 1: '(2.8, 3.6]', 2: '5.9', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica     {'Iris-setosa': 1.9223691038652921e-128, 'Iris-virginica': 0.056632693351643164, 'Iris-versicolor': 1.136039287761803e-06}
# 9      {0: '4.9', 1: '(2.8, 3.6]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa         {'Iris-setosa': 0.4486941588697446, 'Iris-virginica': 7.07690558115182e-16, 'Iris-versicolor': 3.0605462458498136e-14}
# 10      {0: '6', 1: '(1.998, 2.8]', 2: '4', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor        {'Iris-setosa': 1.760820531842986e-44, 'Iris-virginica': 8.547397726570865e-05, 'Iris-versicolor': 0.07235028432233773}
# 11     {0: '5.4', 1: '(3.6, 4.4]', 2: '1.7', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa       {'Iris-setosa': 0.06620356811814988, 'Iris-virginica': 2.4268597297338953e-15, 'Iris-versicolor': 2.464495917665571e-13}
# 12     {0: '6.5', 1: '(2.8, 3.6]', 2: '5.5', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica       {'Iris-setosa': 6.864310495683021e-106, 'Iris-virginica': 0.07338303455999445, 'Iris-versicolor': 5.478483932751443e-05}
# 13  {0: '6.1', 1: '(1.998, 2.8]', 2: '4.7', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor       {'Iris-setosa': 1.2128166641759882e-69, 'Iris-virginica': 0.0013298384102381692, 'Iris-versicolor': 0.06478117942470382}
# 14     {0: '5.5', 1: '(2.8, 3.6]', 2: '1.3', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa        {'Iris-setosa': 0.11932315986460276, 'Iris-virginica': 3.109356206044653e-16, 'Iris-versicolor': 7.620409974842361e-15}
# 15     {0: '5.2', 1: '(2.8, 3.6]', 2: '1.4', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa        {'Iris-setosa': 0.3824339212993141, 'Iris-virginica': 5.255069109041576e-16, 'Iris-versicolor': 1.8698780889805775e-14}
# 16     {0: '5.2', 1: '(2.8, 3.6]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa         {'Iris-setosa': 0.4272936050237089, 'Iris-virginica': 1.927751158263255e-15, 'Iris-versicolor': 9.889313885726722e-14}
# 17     {0: '5.2', 1: '(3.6, 4.4]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa         {'Iris-setosa': 0.192282122260669, 'Iris-virginica': 1.1339712695666207e-16, 'Iris-versicolor': 5.817243462192191e-15}
# 18     {0: '5.4', 1: '(3.6, 4.4]', 2: '1.3', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa        {'Iris-setosa': 0.0751506619043857, 'Iris-virginica': 1.4283712948032406e-17, 'Iris-versicolor': 3.537524156846483e-16}
# 19  {0: '5.5', 1: '(1.998, 2.8]', 2: '4.4', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 1.1590477089102654e-56, 'Iris-virginica': 0.00018680630831114948, 'Iris-versicolor': 0.052329302662047134}
# 20     {0: '6.7', 1: '(2.8, 3.6]', 2: '5.6', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica       {'Iris-setosa': 5.193832004975827e-112, 'Iris-virginica': 0.0725343026350456, 'Iris-versicolor': 1.7775076424378265e-05}
# 21  {0: '5.5', 1: '(1.998, 2.8]', 2: '3.7', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor       {'Iris-setosa': 1.8640824255838342e-34, 'Iris-virginica': 6.911376827009523e-06, 'Iris-versicolor': 0.01738234926221651}
# 22     {0: '7.2', 1: '(2.8, 3.6]', 2: '5.8', 3: '(0.9, 1.7]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica     {'Iris-setosa': 8.881798400055857e-126, 'Iris-virginica': 0.004709874373003222, 'Iris-versicolor': 1.8893577640164454e-05}
# 23    {0: '6.1', 1: '(2.8, 3.6]', 2: '4.6', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor       {'Iris-setosa': 1.9969027497359147e-64, 'Iris-virginica': 0.0015537037246561966, 'Iris-versicolor': 0.10250053708583567}
# 24       {0: '6', 1: '(1.998, 2.8]', 2: '5', 3: '(0.9, 1.7]', 4: 'Iris-virginica'}   Iris-virginica  Iris-versicolor         {'Iris-setosa': 8.879380182630507e-82, 'Iris-virginica': 0.002261270159694906, 'Iris-versicolor': 0.02567993562026218}
# 25     {0: '6.9', 1: '(2.8, 3.6]', 2: '5.1', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica       {'Iris-setosa': 2.5046006534205088e-89, 'Iris-virginica': 0.04988687571072848, 'Iris-versicolor': 0.0001990926054196996}
# 26  {0: '6.5', 1: '(1.998, 2.8]', 2: '4.6', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor       {'Iris-setosa': 1.7159999361060193e-67, 'Iris-virginica': 0.001292645323554027, 'Iris-versicolor': 0.054498992917654046}
# 27     {0: '5.4', 1: '(2.8, 3.6]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa      {'Iris-setosa': 0.27728472702878126, 'Iris-virginica': 3.3734821640879744e-15, 'Iris-versicolor': 1.7825653770958195e-13}
# 28       {0: '5', 1: '(2.8, 3.6]', 2: '1.3', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa        {'Iris-setosa': 0.28800518595510494, 'Iris-virginica': 7.270200627342615e-17, 'Iris-versicolor': 1.586465580874453e-15}
# 29    {0: '5', 1: '(1.998, 2.8]', 2: '3.5', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 7.638796284429162e-29, 'Iris-virginica': 4.7288698487478483e-07, 'Iris-versicolor': 0.0015670576348503446}
# 30      {0: '6', 1: '(2.8, 3.6]', 2: '4.5', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor        {'Iris-setosa': 2.795116180875547e-60, 'Iris-virginica': 0.0010120237015041754, 'Iris-versicolor': 0.11638984063220682}
# 31     {0: '6.5', 1: '(2.8, 3.6]', 2: '5.2', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica       {'Iris-setosa': 1.5288732598315995e-91, 'Iris-virginica': 0.06192190179328996, 'Iris-versicolor': 0.0003280913787705527}
# 32     {0: '7.7', 1: '(3.6, 4.4]', 2: '6.7', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica  {'Iris-setosa': 2.1002452510376553e-183, 'Iris-virginica': 0.00012800514524314094, 'Iris-versicolor': 1.1249529976391215e-13}
# 33       {0: '5', 1: '(2.8, 3.6]', 2: '1.6', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa        {'Iris-setosa': 0.4017078028051953, 'Iris-virginica': 3.588921991315441e-15, 'Iris-versicolor': 2.3468712305369667e-13}
# 34  {0: '5.5', 1: '(1.998, 2.8]', 2: '3.8', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor      {'Iris-setosa': 2.949337450363724e-37, 'Iris-virginica': 1.2179828845878116e-05, 'Iris-versicolor': 0.024213595978182206}
# 35     {0: '4.4', 1: '(2.8, 3.6]', 2: '1.3', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa         {'Iris-setosa': 0.05922618412148924, 'Iris-virginica': 6.21248459302903e-18, 'Iris-versicolor': 6.763338174064258e-17}
# 36     {0: '5.1', 1: '(2.8, 3.6]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa         {'Iris-setosa': 0.4704692970032294, 'Iris-virginica': 1.410600291777932e-15, 'Iris-versicolor': 6.952113558394385e-14}
# 37    {0: '6.1', 1: '(1.998, 2.8]', 2: '4', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor          {'Iris-setosa': 7.786427215963876e-45, 'Iris-virginica': 9.609067249150343e-05, 'Iris-versicolor': 0.072749772160695}
# 38   {0: '6.4', 1: '(1.998, 2.8]', 2: '5.6', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica      {'Iris-setosa': 9.966479660700461e-112, 'Iris-virginica': 0.04573809268093863, 'Iris-versicolor': 2.3835717858462247e-05}
# 39  {0: '4.9', 1: '(1.998, 2.8]', 2: '3.3', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor      {'Iris-setosa': 3.88857892828869e-24, 'Iris-virginica': 8.535120348342242e-08, 'Iris-versicolor': 0.00035019886707272896}
# 40    {0: '5', 1: '(1.998, 2.8]', 2: '3.3', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 4.144254934903286e-24, 'Iris-virginica': 1.2181507213651628e-07, 'Iris-versicolor': 0.0005380759438831581}
# 41     {0: '7.2', 1: '(2.8, 3.6]', 2: '6.1', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica      {'Iris-setosa': 2.350412627811598e-142, 'Iris-virginica': 0.029350672644676067, 'Iris-versicolor': 3.829452582928031e-08}
# 42     {0: '4.9', 1: '(2.8, 3.6]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa         {'Iris-setosa': 0.4486941588697446, 'Iris-virginica': 7.07690558115182e-16, 'Iris-versicolor': 3.0605462458498136e-14}
# 43       {0: '5', 1: '(2.8, 3.6]', 2: '1.2', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa        {'Iris-setosa': 0.14571322220356311, 'Iris-virginica': 1.859461763750733e-17, 'Iris-versicolor': 2.671129836804549e-16}
# 44    {0: '5.9', 1: '(2.8, 3.6]', 2: '4.8', 3: '(1.7, 2.5]', 4: 'Iris-versicolor'}  Iris-versicolor   Iris-virginica      {'Iris-setosa': 1.0458062167689786e-71, 'Iris-virginica': 0.019029118019255713, 'Iris-versicolor': 0.0021680572629387026}
# Matriz de confusión:
# Clase Predicho   Iris-setosa  Iris-virginica  Iris-versicolor
# Clase Actual
# Iris-setosa               16               0                0
# Iris-virginica             0              12                1
# Iris-versicolor            0               1               15
#
# Iteración: 2
# Tabla de resultados:
#                                                                          Instancia     Clase Actual   Clase Predicha                                                                                                                Probabilidades
# 0      {0: '4.6', 1: '(2.8, 3.6]', 2: '1.4', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa       {'Iris-setosa': 0.2150062009319219, 'Iris-virginica': 2.0141546817549603e-18, 'Iris-versicolor': 6.550704961671197e-17}
# 1    {0: '5.6', 1: '(1.998, 2.8]', 2: '4.9', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica         {'Iris-setosa': 3.749031730034e-92, 'Iris-virginica': 0.007422337683309445, 'Iris-versicolor': 0.0011350911522769686}
# 2      {0: '4.4', 1: '(2.8, 3.6]', 2: '1.3', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa     {'Iris-setosa': 0.04801958159331522, 'Iris-virginica': 1.6632365685905415e-19, 'Iris-versicolor': 2.8495748267801164e-18}
# 3     {0: '6.1', 1: '(1.998, 2.8]', 2: '4', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 5.1236690522029285e-54, 'Iris-virginica': 0.00010732658015616887, 'Iris-versicolor': 0.06961521040498218}
# 4   {0: '6.8', 1: '(1.998, 2.8]', 2: '4.8', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor       {'Iris-setosa': 2.745880166613017e-93, 'Iris-virginica': 0.003089814901928449, 'Iris-versicolor': 0.020069858912842728}
# 5   {0: '5.8', 1: '(1.998, 2.8]', 2: '3.9', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor       {'Iris-setosa': 4.085419298176652e-49, 'Iris-virginica': 3.924937770305024e-05, 'Iris-versicolor': 0.04828707054869613}
# 6      {0: '4.8', 1: '(2.8, 3.6]', 2: '1.4', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa     {'Iris-setosa': 0.43569844181381484, 'Iris-virginica': 5.0074877671659915e-18, 'Iris-versicolor': 1.9395914784328407e-16}
# 7      {0: '5.4', 1: '(2.8, 3.6]', 2: '1.7', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa      {'Iris-setosa': 0.12597771352283843, 'Iris-virginica': 2.9764304318930588e-15, 'Iris-versicolor': 3.710176551465622e-13}
# 8      {0: '5.7', 1: '(3.6, 4.4]', 2: '1.7', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa    {'Iris-setosa': 0.012706449584036097, 'Iris-virginica': 4.1699571303979627e-16, 'Iris-versicolor': 3.4939106243300724e-14}
# 9      {0: '6.5', 1: '(2.8, 3.6]', 2: '5.2', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica     {'Iris-setosa': 7.785728870604441e-111, 'Iris-virginica': 0.05108874045285435, 'Iris-versicolor': 0.00041402597012010127}
# 10  {0: '4.9', 1: '(1.998, 2.8]', 2: '3.3', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor   {'Iris-setosa': 7.554587785368617e-29, 'Iris-virginica': 4.5575292389723204e-08, 'Iris-versicolor': 0.00020905431013291189}
# 11     {0: '6.1', 1: '(2.8, 3.6]', 2: '4.9', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica      {'Iris-setosa': 1.2751836153711356e-92, 'Iris-virginica': 0.024183091705237997, 'Iris-versicolor': 0.002195045024867169}
# 12    {0: '6.7', 1: '(2.8, 3.6]', 2: '4.4', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor        {'Iris-setosa': 1.4293105293877343e-72, 'Iris-virginica': 0.001204624031004226, 'Iris-versicolor': 0.0607117270633063}
# 13     {0: '7.6', 1: '(2.8, 3.6]', 2: '6.6', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica    {'Iris-setosa': 6.820571026815745e-213, 'Iris-virginica': 0.0019418743671717445, 'Iris-versicolor': 8.853592726610276e-12}
# 14     {0: '4.6', 1: '(2.8, 3.6]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa      {'Iris-setosa': 0.22406294836368634, 'Iris-virginica': 8.584548670274681e-18, 'Iris-versicolor': 4.0570588116750767e-16}
# 15     {0: '7.2', 1: '(2.8, 3.6]', 2: '5.8', 3: '(0.9, 1.7]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica  {'Iris-setosa': 1.9948577991802104e-152, 'Iris-virginica': 0.0057813449850868635, 'Iris-versicolor': 2.0466040818244066e-05}
# 16   {0: '5.8', 1: '(1.998, 2.8]', 2: '5.1', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica    {'Iris-setosa': 3.0579693831685804e-103, 'Iris-virginica': 0.016271726364976834, 'Iris-versicolor': 0.0007011114002989186}
# 17     {0: '7.9', 1: '(3.6, 4.4]', 2: '6.4', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 7.277012101082126e-202, 'Iris-virginica': 0.00011004210842548894, 'Iris-versicolor': 7.502963668869964e-13}
# 18     {0: '5.4', 1: '(3.6, 4.4]', 2: '1.3', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa      {'Iris-setosa': 0.10077263662856172, 'Iris-virginica': 6.458543946576412e-19, 'Iris-versicolor': 1.5020915633595475e-17}
# 19     {0: '5.1', 1: '(3.6, 4.4]', 2: '1.9', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa      {'Iris-setosa': 0.01117810078019031, 'Iris-virginica': 1.0719203454985453e-15, 'Iris-versicolor': 1.876283441592881e-13}
# 20       {0: '5', 1: '(2.8, 3.6]', 2: '1.6', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa      {'Iris-setosa': 0.4522521273196463, 'Iris-virginica': 1.9788332390033538e-16, 'Iris-versicolor': 1.7571811674826707e-14}
# 21     {0: '4.9', 1: '(2.8, 3.6]', 2: '1.4', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa         {'Iris-setosa': 0.531910606365982, 'Iris-virginica': 7.611253216852845e-18, 'Iris-versicolor': 3.138255448655356e-16}
# 22   {0: '6.1', 1: '(1.998, 2.8]', 2: '5.6', 3: '(0.9, 1.7]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica     {'Iris-setosa': 2.6012167584013934e-133, 'Iris-virginica': 0.00615179696483976, 'Iris-versicolor': 0.0012849374804329947}
# 23       {0: '7.2', 1: '(2.8, 3.6]', 2: '6', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica      {'Iris-setosa': 1.323495760052879e-165, 'Iris-virginica': 0.02403601034498455, 'Iris-versicolor': 9.952283506600706e-08}
# 24     {0: '5.4', 1: '(3.6, 4.4]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa      {'Iris-setosa': 0.15404689987142772, 'Iris-virginica': 1.2159011750161669e-17, 'Iris-versicolor': 6.129388900383608e-16}
# 25       {0: '5', 1: '(2.8, 3.6]', 2: '1.4', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa       {'Iris-setosa': 0.5861580256794408, 'Iris-virginica': 1.1289488555327943e-17, 'Iris-versicolor': 4.873536868096052e-16}
# 26       {0: '6.3', 1: '(2.8, 3.6]', 2: '6', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica     {'Iris-setosa': 8.85816195214314e-159, 'Iris-virginica': 0.036311493483089166, 'Iris-versicolor': 1.4611431043873956e-06}
# 27     {0: '6.2', 1: '(2.8, 3.6]', 2: '5.4', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica     {'Iris-setosa': 1.7229179723311166e-120, 'Iris-virginica': 0.05073147712864504, 'Iris-versicolor': 0.0002025890665612887}
# 28     {0: '7.7', 1: '(3.6, 4.4]', 2: '6.7', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 4.4696504423588614e-222, 'Iris-virginica': 6.599862170287131e-05, 'Iris-versicolor': 5.926371944456678e-14}
# 29     {0: '7.1', 1: '(2.8, 3.6]', 2: '5.9', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica     {'Iris-setosa': 5.264559165506444e-158, 'Iris-virginica': 0.03249121473181262, 'Iris-versicolor': 4.1330415558250044e-07}
# 30     {0: '6.3', 1: '(2.8, 3.6]', 2: '5.6', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica     {'Iris-setosa': 5.126648202914992e-133, 'Iris-virginica': 0.055086481888633035, 'Iris-versicolor': 4.711053292269569e-05}
# 31    {0: '5.7', 1: '(2.8, 3.6]', 2: '4.2', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor       {'Iris-setosa': 5.248274885667607e-59, 'Iris-virginica': 0.00020941709670686253, 'Iris-versicolor': 0.1115464514210976}
# 32   {0: '6.4', 1: '(1.998, 2.8]', 2: '5.6', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica    {'Iris-setosa': 6.413841067160665e-135, 'Iris-virginica': 0.042551031082700974, 'Iris-versicolor': 3.0348664072971344e-05}
# 33  {0: '5.7', 1: '(1.998, 2.8]', 2: '4.1', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor        {'Iris-setosa': 2.44696713825656e-56, 'Iris-virginica': 9.453154783137661e-05, 'Iris-versicolor': 0.07055235203189811}
# 34     {0: '6.9', 1: '(2.8, 3.6]', 2: '5.4', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica    {'Iris-setosa': 3.5491169725633163e-125, 'Iris-virginica': 0.05182847283030598, 'Iris-versicolor': 4.4528396133309536e-05}
# 35       {0: '6', 1: '(2.8, 3.6]', 2: '4.8', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica      {'Iris-setosa': 3.826268214398115e-87, 'Iris-virginica': 0.016863877217159685, 'Iris-versicolor': 0.0029385367894295498}
# 36    {0: '6.4', 1: '(2.8, 3.6]', 2: '4.5', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor       {'Iris-setosa': 5.336132802096882e-75, 'Iris-virginica': 0.0017420611793149882, 'Iris-versicolor': 0.11245001912966893}
# 37    {0: '5.5', 1: '(1.998, 2.8]', 2: '4', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor      {'Iris-setosa': 5.306768713919199e-52, 'Iris-virginica': 3.5069188274601854e-05, 'Iris-versicolor': 0.04024328326400894}
# 38     {0: '6.7', 1: '(2.8, 3.6]', 2: '5.2', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica    {'Iris-setosa': 3.220507609754302e-112, 'Iris-virginica': 0.050160466084929474, 'Iris-versicolor': 0.00025775763461626617}
# 39  {0: '5.5', 1: '(1.998, 2.8]', 2: '3.8', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 9.207267903346671e-45, 'Iris-virginica': 1.1114253687441926e-05, 'Iris-versicolor': 0.021761297967203906}
# 40     {0: '4.4', 1: '(2.8, 3.6]', 2: '1.4', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa      {'Iris-setosa': 0.07043842746234033, 'Iris-virginica': 7.346712368083709e-19, 'Iris-versicolor': 1.8774897406024107e-17}
# 41   {0: '4.5', 1: '(1.998, 2.8]', 2: '1.3', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa     {'Iris-setosa': 0.004204922857747176, 'Iris-virginica': 2.0443932149969568e-19, 'Iris-versicolor': 4.003324217386984e-18}
# 42     {0: '5.1', 1: '(2.8, 3.6]', 2: '1.4', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa       {'Iris-setosa': 0.5830612818320869, 'Iris-virginica': 1.6340832868299545e-17, 'Iris-versicolor': 7.264038884639694e-16}
# 43     {0: '5.2', 1: '(2.8, 3.6]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa       {'Iris-setosa': 0.5455771505746208, 'Iris-virginica': 9.837405626803488e-17, 'Iris-versicolor': 6.4359589987120985e-15}
# 44  {0: '5.7', 1: '(1.998, 2.8]', 2: '3.5', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor   {'Iris-setosa': 1.6432236669798144e-35, 'Iris-virginica': 2.4285908501176465e-06, 'Iris-versicolor': 0.0076955596229404824}
# Matriz de confusión:
# Clase Predicho   Iris-setosa  Iris-virginica  Iris-versicolor
# Clase Actual
# Iris-setosa               16               0                0
# Iris-virginica             0              18                0
# Iris-versicolor            0               0               11
#
# Iteración: 3
# Tabla de resultados:
#                                                                          Instancia     Clase Actual   Clase Predicha                                                                                                              Probabilidades
# 0        {0: '6.3', 1: '(2.8, 3.6]', 2: '6', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica  {'Iris-setosa': 1.0177035647022436e-162, 'Iris-virginica': 0.048510099409897756, 'Iris-versicolor': 7.824810610663556e-06}
# 1   {0: '5.6', 1: '(1.998, 2.8]', 2: '4.2', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 4.4537042791552145e-62, 'Iris-virginica': 7.02684799278949e-05, 'Iris-versicolor': 0.07567493165447423}
# 2      {0: '5.1', 1: '(2.8, 3.6]', 2: '1.4', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa    {'Iris-setosa': 0.5016865700806421, 'Iris-virginica': 1.3517594777524235e-18, 'Iris-versicolor': 4.6317826606698225e-11}
# 3      {0: '7.1', 1: '(2.8, 3.6]', 2: '5.9', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 5.133327558783218e-160, 'Iris-virginica': 0.04558933966409859, 'Iris-versicolor': 1.3975441629420707e-06}
# 4      {0: '5.3', 1: '(3.6, 4.4]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa     {'Iris-setosa': 0.14113583120621553, 'Iris-virginica': 7.880997232415765e-19, 'Iris-versicolor': 1.842658554032073e-11}
# 5      {0: '5.2', 1: '(2.8, 3.6]', 2: '1.4', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa      {'Iris-setosa': 0.4420238516738321, 'Iris-virginica': 2.010431512327818e-18, 'Iris-versicolor': 6.245750190446275e-11}
# 6        {0: '4.6', 1: '(2.8, 3.6]', 2: '1', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa  {'Iris-setosa': 0.011582338142830918, 'Iris-virginica': 1.8960633027743035e-22, 'Iris-versicolor': 3.7214303304435366e-14}
# 7     {0: '5.7', 1: '(2.8, 3.6]', 2: '4.2', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor   {'Iris-setosa': 5.5684591284499056e-61, 'Iris-virginica': 0.00011926214176734577, 'Iris-versicolor': 0.07840673191924029}
# 8      {0: '5.4', 1: '(3.6, 4.4]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa    {'Iris-setosa': 0.10840234780577512, 'Iris-virginica': 1.1099660140708568e-18, 'Iris-versicolor': 2.298754250618996e-11}
# 9   {0: '5.5', 1: '(1.998, 2.8]', 2: '3.7', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor    {'Iris-setosa': 7.0487835630743654e-43, 'Iris-virginica': 2.613172113216958e-06, 'Iris-versicolor': 0.03586370057145834}
# 10  {0: '5.7', 1: '(1.998, 2.8]', 2: '4.1', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 3.573537761381903e-58, 'Iris-virginica': 5.386095893685338e-05, 'Iris-versicolor': 0.08090214983993649}
# 11     {0: '5.4', 1: '(2.8, 3.6]', 2: '1.7', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa    {'Iris-setosa': 0.08949359490772778, 'Iris-virginica': 3.579716860677054e-16, 'Iris-versicolor': 2.8816180570972184e-09}
# 12       {0: '5', 1: '(2.8, 3.6]', 2: '1.6', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa     {'Iris-setosa': 0.3530071074590704, 'Iris-virginica': 1.8069705965495084e-17, 'Iris-versicolor': 3.214284262910154e-10}
# 13     {0: '6.7', 1: '(2.8, 3.6]', 2: '5.7', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica  {'Iris-setosa': 1.7335438678963353e-144, 'Iris-virginica': 0.07430368782658167, 'Iris-versicolor': 2.3483149588155656e-05}
# 14     {0: '5.1', 1: '(3.6, 4.4]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa    {'Iris-setosa': 0.1947227704514542, 'Iris-virginica': 3.6612731633656764e-19, 'Iris-versicolor': 1.0535772221213498e-11}
# 15     {0: '4.8', 1: '(2.8, 3.6]', 2: '1.6', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa    {'Iris-setosa': 0.32264684706639113, 'Iris-virginica': 7.128825483158309e-18, 'Iris-versicolor': 1.4552563682548376e-10}
# 16    {0: '5.5', 1: '(1.998, 2.8]', 2: '4', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor    {'Iris-setosa': 7.727518262756103e-54, 'Iris-virginica': 1.7707466778442018e-05, 'Iris-versicolor': 0.05833840449556283}
# 17     {0: '4.9', 1: '(2.8, 3.6]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa     {'Iris-setosa': 0.5104022153714528, 'Iris-virginica': 2.5930405266237238e-18, 'Iris-versicolor': 7.218357619203024e-11}
# 18    {0: '6.6', 1: '(2.8, 3.6]', 2: '4.6', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor    {'Iris-setosa': 4.1491991522724204e-82, 'Iris-virginica': 0.0020760205036013182, 'Iris-versicolor': 0.02676441203141032}
# 19    {0: '5.9', 1: '(2.8, 3.6]', 2: '4.2', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 1.7712694182704658e-61, 'Iris-virginica': 0.000185132867243082, 'Iris-versicolor': 0.08598036603029145}
# 20   {0: '5.8', 1: '(1.998, 2.8]', 2: '5.1', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 2.569291794363162e-106, 'Iris-virginica': 0.016170557148750105, 'Iris-versicolor': 0.0014404959710738992}
# 21     {0: '6.4', 1: '(2.8, 3.6]', 2: '5.5', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 1.867259325128105e-130, 'Iris-virginica': 0.07243093671778844, 'Iris-versicolor': 0.00015164872751383923}
# 22     {0: '4.8', 1: '(2.8, 3.6]', 2: '1.6', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa    {'Iris-setosa': 0.32264684706639113, 'Iris-virginica': 7.128825483158309e-18, 'Iris-versicolor': 1.4552563682548376e-10}
# 23     {0: '5.1', 1: '(2.8, 3.6]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa     {'Iris-setosa': 0.48680692612863546, 'Iris-virginica': 6.22416437772165e-18, 'Iris-versicolor': 1.4750081109698899e-10}
# 24     {0: '4.8', 1: '(2.8, 3.6]', 2: '1.9', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa   {'Iris-setosa': 0.012717284174552614, 'Iris-virginica': 4.985897149540436e-16, 'Iris-versicolor': 3.2348065109564572e-09}
# 25  {0: '5.5', 1: '(1.998, 2.8]', 2: '3.8', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 2.2204170848185244e-46, 'Iris-virginica': 5.131628604077323e-06, 'Iris-versicolor': 0.0439656799737818}
# 26     {0: '6.1', 1: '(2.8, 3.6]', 2: '4.9', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica     {'Iris-setosa': 4.225335294260158e-95, 'Iris-virginica': 0.02369005340393198, 'Iris-versicolor': 0.0024339646397190723}
# 27     {0: '6.5', 1: '(2.8, 3.6]', 2: '5.8', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 4.764657022294329e-150, 'Iris-virginica': 0.06927654704896943, 'Iris-versicolor': 2.1328890900981764e-05}
# 28    {0: '6.7', 1: '(2.8, 3.6]', 2: '4.7', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor    {'Iris-setosa': 1.7746116508424546e-87, 'Iris-virginica': 0.002886881729838347, 'Iris-versicolor': 0.016990542050915085}
# 29     {0: '5.1', 1: '(2.8, 3.6]', 2: '1.4', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa    {'Iris-setosa': 0.5016865700806421, 'Iris-virginica': 1.3517594777524235e-18, 'Iris-versicolor': 4.6317826606698225e-11}
# 30  {0: '6.1', 1: '(1.998, 2.8]', 2: '4.7', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor   {'Iris-setosa': 3.2616506353980186e-86, 'Iris-virginica': 0.0015735661811571615, 'Iris-versicolor': 0.056005453528742644}
# 31   {0: '4.9', 1: '(1.998, 2.8]', 2: '4.5', 3: '(0.9, 1.7]', 4: 'Iris-virginica'}   Iris-virginica  Iris-versicolor     {'Iris-setosa': 1.016294510115114e-74, 'Iris-virginica': 2.053377349510002e-05, 'Iris-versicolor': 0.01069729329072517}
# 32    {0: '5.6', 1: '(2.8, 3.6]', 2: '4.5', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor    {'Iris-setosa': 5.182040325740665e-74, 'Iris-virginica': 0.0003571812208162868, 'Iris-versicolor': 0.061646025595278556}
# 33     {0: '6.5', 1: '(2.8, 3.6]', 2: '5.5', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 6.741258731147585e-131, 'Iris-virginica': 0.07559884581470541, 'Iris-versicolor': 0.00012332418966243922}
# 34      {0: '6', 1: '(1.998, 2.8]', 2: '4', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 5.235145940477294e-55, 'Iris-virginica': 5.690958710641992e-05, 'Iris-versicolor': 0.08096649514545863}
# 35    {0: '6.4', 1: '(2.8, 3.6]', 2: '4.3', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 1.671026550016465e-67, 'Iris-virginica': 0.0005630291564468471, 'Iris-versicolor': 0.05460010206176264}
# 36    {0: '5.7', 1: '(2.8, 3.6]', 2: '4.2', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor   {'Iris-setosa': 5.5684591284499056e-61, 'Iris-virginica': 0.00011926214176734577, 'Iris-versicolor': 0.07840673191924029}
# 37     {0: '5.2', 1: '(2.8, 3.6]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa      {'Iris-setosa': 0.42891375879224675, 'Iris-virginica': 9.257013846639134e-18, 'Iris-versicolor': 1.98898196761843e-10}
# 38  {0: '6.3', 1: '(1.998, 2.8]', 2: '4.4', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 8.372610497348817e-73, 'Iris-virginica': 0.0006311671773848472, 'Iris-versicolor': 0.06612386352425981}
# 39     {0: '6.3', 1: '(1.998, 2.8]', 2: '5', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 1.849748528201918e-102, 'Iris-virginica': 0.028470194737817915, 'Iris-versicolor': 0.0015607039802872178}
# 40     {0: '5.7', 1: '(3.6, 4.4]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa     {'Iris-setosa': 0.03253924102136758, 'Iris-virginica': 2.633365494696536e-18, 'Iris-versicolor': 3.534022414353642e-11}
# 41       {0: '5', 1: '(2.8, 3.6]', 2: '1.6', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa     {'Iris-setosa': 0.3530071074590704, 'Iris-virginica': 1.8069705965495084e-17, 'Iris-versicolor': 3.214284262910154e-10}
# 42       {0: '5', 1: '(2.8, 3.6]', 2: '1.6', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa     {'Iris-setosa': 0.3530071074590704, 'Iris-virginica': 1.8069705965495084e-17, 'Iris-versicolor': 3.214284262910154e-10}
# 43    {0: '6.3', 1: '(2.8, 3.6]', 2: '4.7', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor    {'Iris-setosa': 1.1983114787955989e-85, 'Iris-virginica': 0.0025687751549543095, 'Iris-versicolor': 0.04199117178760811}
# 44       {0: '7.2', 1: '(2.8, 3.6]', 2: '6', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 1.6622214060344769e-167, 'Iris-virginica': 0.03417617579229354, 'Iris-versicolor': 4.258053172139199e-07}
# Matriz de confusión:
# Clase Predicho   Iris-setosa  Iris-virginica  Iris-versicolor
# Clase Actual
# Iris-setosa               18               0                0
# Iris-virginica             0              10                0
# Iris-versicolor            0               1               16
#
# Iteración: 4
# Tabla de resultados:
#                                                                          Instancia     Clase Actual   Clase Predicha                                                                                                              Probabilidades
# 0       {0: '6', 1: '(2.8, 3.6]', 2: '4.5', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 2.454627618767216e-94, 'Iris-virginica': 0.0009368098677172988, 'Iris-versicolor': 0.08938326679824461}
# 1      {0: '5.4', 1: '(3.6, 4.4]', 2: '1.7', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa     {'Iris-setosa': 0.01033359687995044, 'Iris-virginica': 1.815397534182443e-15, 'Iris-versicolor': 5.122808304241033e-13}
# 2     {0: '5.6', 1: '(2.8, 3.6]', 2: '4.1', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor    {'Iris-setosa': 1.7828529350342315e-71, 'Iris-virginica': 7.241158500044652e-05, 'Iris-versicolor': 0.06812756426498737}
# 3      {0: '4.7', 1: '(2.8, 3.6]', 2: '1.6', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa     {'Iris-setosa': 0.2826685635697788, 'Iris-virginica': 2.6206017311508755e-16, 'Iris-versicolor': 9.986498614025505e-14}
# 4      {0: '6.2', 1: '(2.8, 3.6]', 2: '5.4', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 4.597055970918989e-155, 'Iris-virginica': 0.060076635929163305, 'Iris-versicolor': 0.0002592964881775803}
# 5     {0: '5.5', 1: '(1.998, 2.8]', 2: '4', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor    {'Iris-setosa': 1.009785283472502e-67, 'Iris-virginica': 2.6403831719064312e-05, 'Iris-versicolor': 0.05324673065224032}
# 6   {0: '5.6', 1: '(1.998, 2.8]', 2: '3.9', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor    {'Iris-setosa': 3.998519062689876e-63, 'Iris-virginica': 2.2315019784268725e-05, 'Iris-versicolor': 0.05037262238280756}
# 7   {0: '5.7', 1: '(1.998, 2.8]', 2: '3.5', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor   {'Iris-setosa': 4.543545235118212e-46, 'Iris-virginica': 2.9799805642490858e-06, 'Iris-versicolor': 0.013520203827086495}
# 8      {0: '7.7', 1: '(2.8, 3.6]', 2: '6.1', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica  {'Iris-setosa': 1.2052032416238413e-221, 'Iris-virginica': 0.005203987708391598, 'Iris-versicolor': 9.287402436229555e-10}
# 9      {0: '6.7', 1: '(2.8, 3.6]', 2: '5.6', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 8.085610164353522e-173, 'Iris-virginica': 0.07297612288269467, 'Iris-versicolor': 2.0900456159651047e-05}
# 10   {0: '5.8', 1: '(1.998, 2.8]', 2: '5.1', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica  {'Iris-setosa': 1.8337352785062672e-133, 'Iris-virginica': 0.017680045613163664, 'Iris-versicolor': 0.0015533264328710657}
# 11     {0: '6.7', 1: '(2.8, 3.6]', 2: '5.7', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica    {'Iris-setosa': 8.434988262255081e-181, 'Iris-virginica': 0.07094630679502383, 'Iris-versicolor': 9.908075977676233e-06}
# 12   {0: '6.2', 1: '(1.998, 2.8]', 2: '4.8', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica     {'Iris-setosa': 8.705158965878057e-115, 'Iris-virginica': 0.02072520345490285, 'Iris-versicolor': 0.003796068843904078}
# 13       {0: '5', 1: '(2.8, 3.6]', 2: '1.6', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa    {'Iris-setosa': 0.33879475328033903, 'Iris-virginica': 1.4305473296572104e-15, 'Iris-versicolor': 4.113591989353155e-13}
# 14      {0: '6.7', 1: '(2.8, 3.6]', 2: '5', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 7.138702636870413e-129, 'Iris-virginica': 0.00519172475621304, 'Iris-versicolor': 0.007007490021175557}
# 15      {0: '6', 1: '(1.998, 2.8]', 2: '4', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 5.456856141751195e-69, 'Iris-virginica': 9.946107424616896e-05, 'Iris-versicolor': 0.07631326899933735}
# 16       {0: '6', 1: '(1.998, 2.8]', 2: '5', 3: '(0.9, 1.7]', 4: 'Iris-virginica'}   Iris-virginica  Iris-versicolor   {'Iris-setosa': 3.2961468508184356e-127, 'Iris-virginica': 0.002677744478578106, 'Iris-versicolor': 0.029471248195974405}
# 17   {0: '6.4', 1: '(1.998, 2.8]', 2: '5.3', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 6.561205051375075e-150, 'Iris-virginica': 0.05384771661791537, 'Iris-versicolor': 0.00035205919905234497}
# 18    {0: '6.3', 1: '(2.8, 3.6]', 2: '4.7', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 1.727101114422465e-107, 'Iris-virginica': 0.002524991719684795, 'Iris-versicolor': 0.04804447327635839}
# 19       {0: '5', 1: '(2.8, 3.6]', 2: '1.4', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa    {'Iris-setosa': 0.8045308732033467, 'Iris-virginica': 1.1466036891509863e-16, 'Iris-versicolor': 1.6639557669885326e-14}
# 20     {0: '5.1', 1: '(3.6, 4.4]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa     {'Iris-setosa': 0.11473796209388117, 'Iris-virginica': 4.234362618167272e-17, 'Iris-versicolor': 9.602348161299159e-15}
# 21     {0: '7.2', 1: '(2.8, 3.6]', 2: '5.8', 3: '(0.9, 1.7]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 4.215538850674006e-192, 'Iris-virginica': 0.003920041844211812, 'Iris-versicolor': 5.528588151431154e-06}
# 22    {0: '6.9', 1: '(2.8, 3.6]', 2: '4.9', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor    {'Iris-setosa': 2.2968473300938818e-123, 'Iris-virginica': 0.00362194691121775, 'Iris-versicolor': 0.004516934667433548}
# 23     {0: '5.7', 1: '(3.6, 4.4]', 2: '1.7', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa   {'Iris-setosa': 0.0027563283239801983, 'Iris-virginica': 4.9154758258381354e-15, 'Iris-versicolor': 8.29994884717011e-13}
# 24     {0: '5.2', 1: '(3.6, 4.4]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa    {'Iris-setosa': 0.09833342754660061, 'Iris-virginica': 6.745084497576166e-17, 'Iris-versicolor': 1.3471684872985795e-14}
# 25    {0: '5', 1: '(1.998, 2.8]', 2: '3.5', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor   {'Iris-setosa': 3.643256032557483e-45, 'Iris-virginica': 1.8273549793999482e-07, 'Iris-versicolor': 0.002354140663470754}
# 26     {0: '6.8', 1: '(2.8, 3.6]', 2: '5.5', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 1.371919205687619e-165, 'Iris-virginica': 0.06793982227780293, 'Iris-versicolor': 2.8708900050498822e-05}
# 27     {0: '5.1', 1: '(3.6, 4.4]', 2: '1.6', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa    {'Iris-setosa': 0.05997946713814133, 'Iris-virginica': 1.4725903412054096e-16, 'Iris-versicolor': 4.641084783410793e-14}
# 28     {0: '6.4', 1: '(2.8, 3.6]', 2: '5.3', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica  {'Iris-setosa': 1.7059133133575194e-148, 'Iris-virginica': 0.06627411276051122, 'Iris-versicolor': 0.00032691211340574893}
# 29     {0: '6.3', 1: '(2.8, 3.6]', 2: '5.6', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 7.141653643716762e-171, 'Iris-virginica': 0.06877053189089018, 'Iris-versicolor': 5.9432678058977336e-05}
# 30  {0: '6.8', 1: '(1.998, 2.8]', 2: '4.8', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor   {'Iris-setosa': 1.0486914526123642e-117, 'Iris-virginica': 0.002614052548724994, 'Iris-versicolor': 0.009895546638798719}
# 31  {0: '5.5', 1: '(1.998, 2.8]', 2: '3.7', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 6.423192655743898e-54, 'Iris-virginica': 5.362419775501957e-06, 'Iris-versicolor': 0.02347710214300073}
# 32  {0: '5.8', 1: '(1.998, 2.8]', 2: '3.9', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor    {'Iris-setosa': 1.3367795195043717e-63, 'Iris-virginica': 3.921860154949045e-05, 'Iris-versicolor': 0.06081554162766522}
# 33     {0: '5.1', 1: '(2.8, 3.6]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa     {'Iris-setosa': 0.596637402888182, 'Iris-virginica': 6.7749801890676355e-16, 'Iris-versicolor': 1.2483052609688909e-13}
# 34     {0: '5.4', 1: '(2.8, 3.6]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa     {'Iris-setosa': 0.30301695932729655, 'Iris-virginica': 2.477450680509505e-15, 'Iris-versicolor': 3.016912253039141e-13}
# 35     {0: '5.7', 1: '(1.998, 2.8]', 2: '5', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 2.3529036725620553e-126, 'Iris-virginica': 0.011575254993436873, 'Iris-versicolor': 0.002170679841223896}
# 36     {0: '6.7', 1: '(2.8, 3.6]', 2: '5.7', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica    {'Iris-setosa': 8.434988262255081e-181, 'Iris-virginica': 0.07094630679502383, 'Iris-versicolor': 9.908075977676233e-06}
# 37    {0: '6.7', 1: '(2.8, 3.6]', 2: '4.7', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 1.955382747793533e-109, 'Iris-virginica': 0.0026794049856391044, 'Iris-versicolor': 0.0168956109706111}
# 38    {0: '6.2', 1: '(2.8, 3.6]', 2: '4.3', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor      {'Iris-setosa': 8.58470900316231e-84, 'Iris-virginica': 0.0006130813199053956, 'Iris-versicolor': 0.08168616289232776}
# 39     {0: '5.5', 1: '(3.6, 4.4]', 2: '1.4', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa    {'Iris-setosa': 0.050018823374655026, 'Iris-virginica': 6.219970602239557e-17, 'Iris-versicolor': 5.571022190498435e-15}
# 40     {0: '6.9', 1: '(2.8, 3.6]', 2: '5.1', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 6.907402228834595e-137, 'Iris-virginica': 0.044443312535770406, 'Iris-versicolor': 0.0001695665562613527}
# 41     {0: '7.7', 1: '(3.6, 4.4]', 2: '6.7', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica  {'Iris-setosa': 1.0571854737102639e-278, 'Iris-virginica': 6.778928351302241e-05, 'Iris-versicolor': 6.34106910324315e-14}
# 42       {0: '5', 1: '(2.8, 3.6]', 2: '1.6', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa    {'Iris-setosa': 0.33879475328033903, 'Iris-virginica': 1.4305473296572104e-15, 'Iris-versicolor': 4.113591989353155e-13}
# 43    {0: '6.6', 1: '(2.8, 3.6]', 2: '4.4', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 3.7303658608990935e-91, 'Iris-virginica': 0.0010828321312414204, 'Iris-versicolor': 0.0339656944165432}
# 44     {0: '6.9', 1: '(2.8, 3.6]', 2: '5.7', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 5.8423845351328936e-182, 'Iris-virginica': 0.05981593343087291, 'Iris-versicolor': 4.500611399006626e-06}
# Matriz de confusión:
# Clase Predicho   Iris-setosa  Iris-virginica  Iris-versicolor
# Clase Actual
# Iris-setosa               12               0                0
# Iris-virginica             0              16                0
# Iris-versicolor            0               1               16
#
# Iteración: 5
# Tabla de resultados:
#                                                                          Instancia     Clase Actual   Clase Predicha                                                                                                                Probabilidades
# 0      {0: '6.5', 1: '(2.8, 3.6]', 2: '5.8', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica     {'Iris-setosa': 4.548083171847218e-185, 'Iris-virginica': 0.09046054069353779, 'Iris-versicolor': 2.1066878772665175e-05}
# 1     {0: '6.3', 1: '(2.8, 3.6]', 2: '4.7', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor      {'Iris-setosa': 4.7264025981933856e-105, 'Iris-virginica': 0.004148473879746552, 'Iris-versicolor': 0.06433673056708494}
# 2      {0: '5.2', 1: '(3.6, 4.4]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa       {'Iris-setosa': 0.24601103218346956, 'Iris-virginica': 1.874177371715288e-24, 'Iris-versicolor': 4.003682886731899e-14}
# 3   {0: '5.5', 1: '(1.998, 2.8]', 2: '3.8', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor      {'Iris-setosa': 1.172635173068029e-53, 'Iris-virginica': 8.716246911402417e-07, 'Iris-versicolor': 0.027043211802005987}
# 4     {0: '5.5', 1: '(1.998, 2.8]', 2: '4', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 1.1797889504797897e-62, 'Iris-virginica': 4.751322940659831e-06, 'Iris-versicolor': 0.043566365177282504}
# 5   {0: '6.1', 1: '(1.998, 2.8]', 2: '4.7', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor       {'Iris-setosa': 2.8150088012763504e-104, 'Iris-virginica': 0.00232043560873089, 'Iris-versicolor': 0.07263061810394981}
# ...
# 32  {0: '5.8', 1: '(1.998, 2.8]', 2: '4.1', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor    {'Iris-setosa': 1.2349938927354858e-53, 'Iris-virginica': 4.4493536936633063e-05, 'Iris-versicolor': 0.07426403443213135}
# 33      {0: '6', 1: '(1.998, 2.8]', 2: '4', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor      {'Iris-setosa': 8.967664446942303e-51, 'Iris-virginica': 3.5861149643779763e-05, 'Iris-versicolor': 0.0693821306990951}
# 34     {0: '5.5', 1: '(3.6, 4.4]', 2: '1.4', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa      {'Iris-setosa': 0.0685857939824618, 'Iris-virginica': 5.168254715237692e-19, 'Iris-versicolor': 1.8832701462751677e-12}
# 35    {0: '5.7', 1: '(2.8, 3.6]', 2: '4.2', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 7.861266021278843e-56, 'Iris-virginica': 0.00012166790615555176, 'Iris-versicolor': 0.07321719383532126}
# 36    {0: '6.6', 1: '(2.8, 3.6]', 2: '4.4', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 3.138280367846482e-68, 'Iris-virginica': 0.0008243883921901489, 'Iris-versicolor': 0.037718358756046254}
# 37     {0: '4.8', 1: '(2.8, 3.6]', 2: '1.4', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa      {'Iris-setosa': 0.42495087851684776, 'Iris-virginica': 8.418183132684417e-19, 'Iris-versicolor': 4.852385162079921e-12}
# 38  {0: '6.1', 1: '(1.998, 2.8]', 2: '4.7', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor       {'Iris-setosa': 1.3349650125734329e-79, 'Iris-virginica': 0.00094296634434694, 'Iris-versicolor': 0.04753406842171162}
# 39   {0: '6.3', 1: '(1.998, 2.8]', 2: '5.1', 3: '(0.9, 1.7]', 4: 'Iris-virginica'}   Iris-virginica  Iris-versicolor     {'Iris-setosa': 6.034522255655431e-100, 'Iris-virginica': 0.003054912668540015, 'Iris-versicolor': 0.012228495825962563}
# 40     {0: '5.4', 1: '(3.6, 4.4]', 2: '1.7', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa      {'Iris-setosa': 0.05091832730271404, 'Iris-virginica': 3.278739484209979e-17, 'Iris-versicolor': 6.283108829874628e-11}
# 41     {0: '4.6', 1: '(2.8, 3.6]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa      {'Iris-setosa': 0.25196706503044036, 'Iris-virginica': 1.494130861176698e-18, 'Iris-versicolor': 8.014022513473121e-12}
# 42   {0: '6.7', 1: '(1.998, 2.8]', 2: '5.8', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica    {'Iris-setosa': 9.499685219700547e-142, 'Iris-virginica': 0.045121293866036694, 'Iris-versicolor': 1.011950855027552e-05}
# 43    {0: '5.8', 1: '(1.998, 2.8]', 2: '4', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 5.281311746625476e-50, 'Iris-virginica': 2.5458983320696528e-05, 'Iris-versicolor': 0.06807236027631774}
# 44   {0: '7.7', 1: '(1.998, 2.8]', 2: '6.7', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica    {'Iris-setosa': 8.967717788845966e-212, 'Iris-virginica': 0.001023038415393228, 'Iris-versicolor': 5.567372614147172e-11}
# Matriz de confusión:
# Clase Predicho   Iris-setosa  Iris-virginica  Iris-versicolor
# Clase Actual
# Iris-setosa               16               0                0
# Iris-virginica             0              11                0
# Iris-versicolor            0               2               16
#
# Iteración: 10
# Tabla de resultados:
#                                                                          Instancia     Clase Actual   Clase Predicha                                                                                                              Probabilidades
# 0      {0: '4.7', 1: '(2.8, 3.6]', 2: '1.6', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa     {'Iris-setosa': 0.2096159984430152, 'Iris-virginica': 7.879055389942094e-17, 'Iris-versicolor': 1.1061568786193353e-10}
# 1    {0: '6.4', 1: '(1.998, 2.8]', 2: '5.3', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 2.4380947355513086e-137, 'Iris-virginica': 0.02781617976646034, 'Iris-versicolor': 0.0003030105933445736}
# 2     {0: '5.6', 1: '(2.8, 3.6]', 2: '4.1', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor    {'Iris-setosa': 2.3074166420687026e-65, 'Iris-virginica': 4.011657872757586e-05, 'Iris-versicolor': 0.06670452407112049}
# 3        {0: '6', 1: '(2.8, 3.6]', 2: '4.8', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica    {'Iris-setosa': 3.94430967687169e-103, 'Iris-virginica': 0.010077047740429215, 'Iris-versicolor': 0.0018767433600657727}
# 4      {0: '6.7', 1: '(2.8, 3.6]', 2: '5.7', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica    {'Iris-setosa': 9.063266801519566e-166, 'Iris-virginica': 0.0731700897757474, 'Iris-versicolor': 2.7954117405886327e-05}
# 5       {0: '6', 1: '(2.8, 3.6]', 2: '4.5', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 2.5980638512524605e-86, 'Iris-virginica': 0.0006443334052266457, 'Iris-versicolor': 0.0853464630367981}
# 6      {0: '5.2', 1: '(2.8, 3.6]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa    {'Iris-setosa': 0.4272341659585313, 'Iris-virginica': 3.0745871792589935e-16, 'Iris-versicolor': 2.0140097631698103e-10}
# 7      {0: '4.8', 1: '(2.8, 3.6]', 2: '1.9', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa   {'Iris-setosa': 0.004665134826274841, 'Iris-virginica': 5.006152438865576e-15, 'Iris-versicolor': 3.4272558323244832e-09}
# 8      {0: '4.8', 1: '(2.8, 3.6]', 2: '1.6', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa    {'Iris-setosa': 0.24957008100170686, 'Iris-virginica': 1.406381110104862e-16, 'Iris-versicolor': 1.6546794101057772e-10}
# 9   {0: '5.8', 1: '(1.998, 2.8]', 2: '3.9', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor   {'Iris-setosa': 4.224293313619822e-58, 'Iris-virginica': 1.5303245653005366e-05, 'Iris-versicolor': 0.059514777404047925}
# 10     {0: '7.3', 1: '(2.8, 3.6]', 2: '6.3', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica    {'Iris-setosa': 4.909625849657029e-217, 'Iris-virginica': 0.027175497391284758, 'Iris-versicolor': 6.85803983395383e-08}
# 11   {0: '5.8', 1: '(1.998, 2.8]', 2: '5.1', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica  {'Iris-setosa': 2.9728999014963663e-122, 'Iris-virginica': 0.006495281482646448, 'Iris-versicolor': 0.0007665982473165193}
# 12  {0: '6.3', 1: '(1.998, 2.8]', 2: '4.4', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor    {'Iris-setosa': 2.331022208273783e-83, 'Iris-virginica': 0.00043394024420781197, 'Iris-versicolor': 0.07262704710382929}
# 13     {0: '5.4', 1: '(2.8, 3.6]', 2: '1.7', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa      {'Iris-setosa': 0.0663217644119039, 'Iris-virginica': 8.502811163652206e-15, 'Iris-versicolor': 2.677733869182263e-09}
# 14  {0: '5.6', 1: '(1.998, 2.8]', 2: '3.9', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor       {'Iris-setosa': 1.10139982751085e-57, 'Iris-virginica': 8.23357726708262e-06, 'Iris-versicolor': 0.04930518947060421}
# 15     {0: '5.7', 1: '(1.998, 2.8]', 2: '5', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica  {'Iris-setosa': 9.914057495425418e-116, 'Iris-virginica': 0.0040215486429669755, 'Iris-versicolor': 0.0009545494124617889}
# 16    {0: '5.7', 1: '(2.8, 3.6]', 2: '4.2', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 2.697776640863331e-70, 'Iris-virginica': 8.772624365990174e-05, 'Iris-versicolor': 0.07904677024269734}
# 17    {0: '5.9', 1: '(2.8, 3.6]', 2: '4.8', 3: '(1.7, 2.5]', 4: 'Iris-versicolor'}  Iris-versicolor   Iris-virginica     {'Iris-setosa': 7.564276787224608e-103, 'Iris-virginica': 0.00793475561188286, 'Iris-versicolor': 0.001852721432771005}
# 18     {0: '6.9', 1: '(2.8, 3.6]', 2: '5.7', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica    {'Iris-setosa': 7.651129894838768e-167, 'Iris-virginica': 0.07286324974737181, 'Iris-versicolor': 1.651164249951995e-05}
# 19    {0: '6.1', 1: '(2.8, 3.6]', 2: '4.6', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 4.668733359309805e-92, 'Iris-virginica': 0.0011133346983758596, 'Iris-versicolor': 0.07579797782042398}
# 20     {0: '5.1', 1: '(3.6, 4.4]', 2: '1.9', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa   {'Iris-setosa': 0.0021939292440339864, 'Iris-virginica': 3.001830325258606e-15, 'Iris-versicolor': 5.900200484879368e-10}
# 21    {0: '5.6', 1: '(2.8, 3.6]', 2: '3.6', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor   {'Iris-setosa': 2.8586777256301856e-44, 'Iris-virginica': 2.5661242400330852e-06, 'Iris-versicolor': 0.02735445311434716}
# 22    {0: '6.4', 1: '(2.8, 3.6]', 2: '4.3', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor    {'Iris-setosa': 2.1372309916501926e-77, 'Iris-virginica': 0.0005878807982733162, 'Iris-versicolor': 0.07028951963986162}
# 23    {0: '5', 1: '(1.998, 2.8]', 2: '3.5', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor   {'Iris-setosa': 2.553326379542762e-41, 'Iris-virginica': 5.992211819084095e-08, 'Iris-versicolor': 0.0049677027172051625}
# 24     {0: '5.2', 1: '(3.6, 4.4]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa    {'Iris-setosa': 0.17988806987727635, 'Iris-virginica': 3.843233974073742e-17, 'Iris-versicolor': 1.2587561019811314e-11}
# 25     {0: '6.8', 1: '(2.8, 3.6]', 2: '5.9', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 1.712339241972245e-181, 'Iris-virginica': 0.06765670553637664, 'Iris-versicolor': 6.6527717801746215e-06}
# 26     {0: '4.9', 1: '(2.8, 3.6]', 2: '1.5', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa      {'Iris-setosa': 0.47020264717835847, 'Iris-virginica': 6.978659864898988e-17, 'Iris-versicolor': 8.06022078460506e-11}
# 27    {0: '6.6', 1: '(2.8, 3.6]', 2: '4.4', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 2.2372018292953796e-83, 'Iris-virginica': 0.001032571888779304, 'Iris-versicolor': 0.04946333874573088}
# 28       {0: '5', 1: '(2.8, 3.6]', 2: '1.4', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa     {'Iris-setosa': 0.5546831076570196, 'Iris-virginica': 3.264888855610277e-17, 'Iris-versicolor': 3.6531358806126046e-11}
# 29   {0: '6.7', 1: '(1.998, 2.8]', 2: '5.8', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 1.4599216269845753e-174, 'Iris-virginica': 0.03994367375658573, 'Iris-versicolor': 1.475485865627838e-05}
# 30     {0: '6.1', 1: '(2.8, 3.6]', 2: '4.9', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 2.138766349026162e-109, 'Iris-virginica': 0.015888678543518633, 'Iris-versicolor': 0.0014799941975969261}
# 31     {0: '6.3', 1: '(1.998, 2.8]', 2: '5', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica  {'Iris-setosa': 1.6211823508606226e-117, 'Iris-virginica': 0.015496535446470908, 'Iris-versicolor': 0.0009354948375188406}
# 32     {0: '7.6', 1: '(2.8, 3.6]', 2: '6.6', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica   {'Iris-setosa': 2.05560203199821e-245, 'Iris-virginica': 0.007479436088664421, 'Iris-versicolor': 1.2833218464936521e-09}
# 33  {0: '5.7', 1: '(1.998, 2.8]', 2: '4.5', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor    {'Iris-setosa': 7.845927931669718e-87, 'Iris-virginica': 0.00016250869932529451, 'Iris-versicolor': 0.06983078476597539}
# 34    {0: '5.5', 1: '(1.998, 2.8]', 2: '4', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor    {'Iris-setosa': 6.503689077887289e-62, 'Iris-virginica': 9.728998390107408e-06, 'Iris-versicolor': 0.049100231440927136}
# 35     {0: '4.9', 1: '(2.8, 3.6]', 2: '1.4', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa      {'Iris-setosa': 0.534610637900573, 'Iris-virginica': 1.935876801689238e-17, 'Iris-versicolor': 2.6060680420260326e-11}
# 36  {0: '5.7', 1: '(1.998, 2.8]', 2: '3.5', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor   {'Iris-setosa': 4.814012758389068e-42, 'Iris-virginica': 1.0509628587725088e-06, 'Iris-versicolor': 0.021275376366733423}
# 37     {0: '5.9', 1: '(2.8, 3.6]', 2: '5.1', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica  {'Iris-setosa': 3.1551343425298515e-121, 'Iris-virginica': 0.015086701694409892, 'Iris-versicolor': 0.0008556572595853432}
# 38  {0: '6.3', 1: '(1.998, 2.8]', 2: '4.9', 3: '(0.9, 1.7]', 4: 'Iris-versicolor'}  Iris-versicolor  Iris-versicolor     {'Iris-setosa': 2.169776756093043e-111, 'Iris-virginica': 0.002001402082294021, 'Iris-versicolor': 0.03630775631958651}
# 39       {0: '5', 1: '(2.8, 3.6]', 2: '1.6', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa       {'Iris-setosa': 0.2877978747791735, 'Iris-virginica': 4.11531884420771e-16, 'Iris-versicolor': 3.358787635490453e-10}
# 40     {0: '6.7', 1: '(2.8, 3.6]', 2: '5.2', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica    {'Iris-setosa': 8.443223879223671e-131, 'Iris-virginica': 0.05377382880061967, 'Iris-versicolor': 0.0002727539117509745}
# 41     {0: '7.1', 1: '(2.8, 3.6]', 2: '5.9', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica  {'Iris-setosa': 3.0816927548215246e-183, 'Iris-virginica': 0.059174875671852846, 'Iris-versicolor': 2.609341806914116e-06}
# 42     {0: '6.3', 1: '(2.8, 3.6]', 2: '5.6', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica    {'Iris-setosa': 1.2206410202641432e-156, 'Iris-virginica': 0.0524697679277469, 'Iris-versicolor': 9.262554505093132e-05}
# 43     {0: '4.8', 1: '(2.8, 3.6]', 2: '1.4', 3: '(0.0976, 0.9]', 4: 'Iris-setosa'}      Iris-setosa      Iris-setosa    {'Iris-setosa': 0.4810053174105596, 'Iris-virginica': 1.1157526760253187e-17, 'Iris-versicolor': 1.7996876789995838e-11}
# 44   {0: '5.8', 1: '(1.998, 2.8]', 2: '5.1', 3: '(1.7, 2.5]', 4: 'Iris-virginica'}   Iris-virginica   Iris-virginica  {'Iris-setosa': 2.9728999014963663e-122, 'Iris-virginica': 0.006495281482646448, 'Iris-versicolor': 0.0007665982473165193}
# Matriz de confusión:
# Clase Predicho   Iris-setosa  Iris-virginica  Iris-versicolor
# Clase Actual
# Iris-setosa               12               0                0
# Iris-virginica             0              17                1
# Iris-versicolor            0               0               15
# --------------------------------------------------
# Matriz de confusión promedio:
# Clase Predicho   Iris-setosa  Iris-virginica  Iris-versicolor
# Clase Actual
# Iris-setosa             15.5             0.0              0.0
# Iris-virginica           0.0            13.4              0.4
# Iris-versicolor          0.0             0.6             15.1
# --------------------------------------------------
# Métricas finales:
# Exactitud (promedio): 0.9777777777777777
# Sensibilidad (promedio): {'Iris-setosa': 1.0, 'Iris-virginica': 0.9571428571428572, 'Iris-versicolor': 0.9741935483870967}
# Especificidad (promedio): {'Iris-setosa': 0.9661016949152542, 'Iris-virginica': 0.9870967741935485, 'Iris-versicolor': 0.9796610169491525}
# Precisión (promedio): {'Iris-setosa': 1.0, 'Iris-virginica': 0.9710144927536232, 'Iris-versicolor': 0.9617834394904459}
# F1-score (promedio): {'Iris-setosa': 1.0, 'Iris-virginica': 0.9640287769784173, 'Iris-versicolor': 0.967948717948718}
# --------------------------------------------------
